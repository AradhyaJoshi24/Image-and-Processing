# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\aradhya joshi\appdata\local\programs\python\python311\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in c:\users\aradhya joshi\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (2.1.2)
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
img = cv2.imread("me.png")

# %%
from matplotlib import pyplot as plt

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
cv2.imwrite("output_image.jpg", img)
print("Image saved successfully.")
# Out:
# Image saved successfully.

# %%
import cv2

# %%
img = cv2.imread("Me.png")

# %%
cv2.imwrite("output.png", img)
cv2.imwrite("output.tiff", img)
cv2.imwrite("output.bmp", img)
cv2.imwrite("output.jpeg", img)

print("Image converted and saved in different formats successfully.")
# Out:
# Image converted and saved in different formats successfully.

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("me.png")

# %%
resized_img = cv2.resize(img, (300, 300))

# %%
original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
resized = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(original)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(resized)
plt.title("Resized Image")
plt.axis("off")

plt.show()

# %%
import cv2
img = cv2.imread(r"D:\Mca 3 sem\Image and processing\me.png")
resized_img = cv2.resize(img, (300, 300))
cv2.imwrite("resized_image.jpg", resized_img)
print("Resized image saved successfully.")
# Out:
# Resized image saved successfully.

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("me.png")

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
cv2.imwrite("grayscale_image.jpg", gray_img)
print("Grayscale image saved successfully.")
# Out:
# Grayscale image saved successfully.

# %%
import cv2

# %%
cap = cv2.VideoCapture("Shooting.mp4")

# %%
while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        print("End of video or cannot read the video.")
        break

    cv2.imshow("Video", frame)

    # Press 'q' to exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# %%
cap = cv2.VideoCapture("Shooting.mp4")

# %%
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    # Save each frame as an image
    filename = f"frame_{frame_count}.jpg"
    cv2.imwrite(filename, frame)

    frame_count += 1

print("Frames extracted successfully.")
# Out:
# Frames extracted successfully.

# %%
cap.release()
